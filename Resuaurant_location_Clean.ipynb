# %%
# Pandas - Data manipulation and analysis library
import pandas as pd
# NumPy - mathematical functions on multi-dimensional arrays and matrices
import numpy as np
import seaborn as sns
# Matplotlib - plotting library to create graphs and charts
import matplotlib.pyplot as plt

# %%
import json
import math
import plotly.express as px
from area import area
from sklearn import neighbors
from scipy import stats

# %%
#conda install -c conda-forge folium
import folium
import folium.plugins

# %%
df_OPA= pd.read_csv(r'C:\Users\user\OneDrive\Desktop\CIS 9660 Group Project\Open_Restaurant_Applications.csv')

# %%
df_subway=pd.read_csv(r'C:\Users\user\OneDrive\Desktop\CIS 9660 Group Project\DOITT_SUBWAY_STATION_01_13SEPT2010.csv')

# %%
df_OPA.head(5)
# Out:
#    objectid                                globalid  \
# 0     12302  {F4FFE759-9440-444D-8301-D9674B698218}
# 1     12301  {58DD8DE5-3E9B-42A1-8259-1DFE769E6A63}
# 2     10289  {096E1404-EBAE-48F5-8DDF-8ABD9D1F57D1}
# 3     10274  {3B982638-4EB7-4BFE-8FA4-29F2DE80833B}
# 4     10259  {2CBACAD1-49B6-4D8D-8F25-A3F415A9C586}
#
#   Seating Interest (Sidewalk/Roadway/Both)                  Restaurant Name  \
# 0                                  roadway                 HERE ARTS CENTER
# 1                                     both                          MEYHANE
# 2                                     both  Prince Laban&Chinese restaurent
# 3                                 sidewalk           Philly Pretzel Factory
# 4                                  roadway                     About Coffee
#
#                           Legal Business Name  \
# 0  HOME FOR CONTEMPORARY THEATRE AND ART, LTD
# 1                                  DINAH CORP
# 2                                Renessa inc.
# 3                      Snacking Made Easy LLC
# 4                            ABOUT COFFEE LLC
#
#                 Doing Business As (DBA) Building Number  \
# 0                      HERE ARTS CENTER       undefined
# 1                               MEYHANE       undefined
# 2  Prince Kababish & Chinese restaurant            3756
# 3                Philly Pretzel Factory             131
# 4                          ABOUT COFFEE              71
#
#                        Street    Borough  Postcode  ...  \
# 0  145 AVENUE OF THE AMERICAS  Manhattan     10013  ...
# 1                166 2 AVENUE  Manhattan     10003  ...
# 2                   74 street     Queens     11372  ...
# 3                     5th Ave   Brooklyn     11217  ...
# 4             SULLIVAN STREET  Manhattan     10012  ...
#
#   healthCompliance_terms      Time of Submission   Latitude  Longitude  \
# 0                    yes  04/22/2021 02:47:00 PM  40.724971 -74.004477
# 1                    yes  04/22/2021 02:41:00 PM  40.730073 -73.986585
# 2                    yes  08/15/2020 04:55:00 PM  40.747630 -73.891596
# 3                    yes  08/15/2020 09:58:00 AM  40.678651 -73.978934
# 4                    yes  08/14/2020 05:08:00 PM  40.724625 -74.003889
#
#   Community Board Council District  Census Tract        BIN           BBL  \
# 0             2.0              3.0          37.0  1087061.0  1.004918e+09
# 1             3.0              2.0          40.0  1006434.0  1.004520e+09
# 2             3.0             25.0         289.0  4029808.0  4.012840e+09
# 3             6.0             39.0         131.0  3019193.0  3.009440e+09
# 4             2.0              3.0          47.0  1007347.0  1.004890e+09
#
#                                       NTA
# 0  SoHo-TriBeCa-Civic Center-Little Italy
# 1                            East Village
# 2                         Jackson Heights
# 3                      Park Slope-Gowanus
# 4  SoHo-TriBeCa-Civic Center-Little Italy
#
# [5 rows x 35 columns]

# %%
df_subway.head(5)
# Out:
#                                NAME  \
# 0  W 4th St - Washington Sq (Lower)
# 1                         Buhre Ave
# 2                           51st St
# 3                           86th St
# 4       Brooklyn Bridge - City Hall
#
#                                         the_geom  \
# 0   POINT (-74.00030814706824 40.73225482650675)
# 1  POINT (-73.83256899924748 40.846810332614844)
# 2  POINT (-73.97192000013308 40.757107333148234)
# 3   POINT (-73.97621799811347 40.78864433404891)
# 4  POINT (-74.00413100111697 40.713065332984044)
#
#                                           URL             LINE
# 0  http://www.mta.info/nyct/subway/index.html          B-D-F-M
# 1  http://www.mta.info/nyct/subway/index.html      6-6 Express
# 2  http://www.mta.info/nyct/subway/index.html    4-6-6 Express
# 3  http://www.mta.info/nyct/subway/index.html              1-2
# 4  http://www.mta.info/nyct/subway/index.html  4-5-6-6 Express

# %%
df_OPA.isnull().sum()
# Out:
# objectid                                       0
# globalid                                       0
# Seating Interest (Sidewalk/Roadway/Both)       0
# Restaurant Name                                0
# Legal Business Name                            0
# Doing Business As (DBA)                        3
# Building Number                                0
# Street                                         0
# Borough                                        0
# Postcode                                       0
# Business Address                               0
# Food Service Establishment Permit #            1
# Sidewalk Dimensions (Length)                   0
# Sidewalk Dimensions (Width)                    0
# Sidewalk Dimensions (Area)                     0
# Roadway Dimensions (Length)                    0
# Roadway Dimensions (Width)                     0
# Roadway Dimensions (Area)                      0
# Approved for Sidewalk Seating                  0
# Approved for Roadway Seating                   0
# Qualify Alcohol                                0
# SLA Serial Number                           1517
# SLA License Type                            1517
# Landmark District or Building                  0
# landmarkDistrict_terms                      4888
# healthCompliance_terms                         0
# Time of Submission                             0
# Latitude                                       0
# Longitude                                      0
# Community Board                                0
# Council District                               0
# Census Tract                                   0
# BIN                                           43
# BBL                                           43
# NTA                                            0
# dtype: int64

# %%
nan_value = float("NaN")
df_OPA.replace("", nan_value, inplace=True)

df_OPA.dropna(subset = ['Latitude','Longitude','Sidewalk Dimensions (Area)','Roadway Dimensions (Area)'], inplace=True)

# %%
group=['Restaurant Name','Latitude','Longitude','Sidewalk Dimensions (Area)','Roadway Dimensions (Area)','Time of Submission']

# %%
df_RestaurantLoc=df_OPA[group]
df_RestaurantLoc
# Out:
#                        Restaurant Name   Latitude  Longitude  \
# 1                              MEYHANE  40.730073 -73.986585
# 2      Prince Laban&Chinese restaurent  40.747630 -73.891596
# 5                        BICKLES TO GO  40.820750 -73.917653
# 9                Le Pain Quotidien GCW  40.754434 -73.979138
# 11            35-09 Ditmars Bagel Corp  40.774763 -73.908748
# ...                                ...        ...        ...
# 12248                       PINK MOOSE  40.759173 -73.962283
# 12249                         JACKSONS  40.742309 -73.953104
# 12254                Astoria Ale House  40.780874 -73.917406
# 12255              KING OF SPADES INC.  40.784739 -73.845776
# 12256                 KASHKAVAL GARDEN  40.766927 -73.986423
#
#       Sidewalk Dimensions (Area) Roadway Dimensions (Area)  \
# 1                            512                       256
# 2                            144                       144
# 5                            100                       160
# 9                             90                       240
# 11                            40                       160
# ...                          ...                       ...
# 12248                        180                       160
# 12249                        616                       476
# 12254                        160                       160
# 12255                         88                       176
# 12256                         30                        30
#
#            Time of Submission
# 1      04/22/2021 02:41:00 PM
# 2      08/15/2020 04:55:00 PM
# 5      08/17/2020 10:29:00 AM
# 9      08/17/2020 09:46:00 AM
# 11     08/16/2020 05:22:00 PM
# ...                       ...
# 12248  12/02/2020 02:37:00 PM
# 12249  07/24/2020 04:31:00 PM
# 12254  07/23/2020 08:56:00 PM
# 12255  08/04/2020 03:27:00 PM
# 12256  06/30/2020 10:33:00 PM
#
# [5699 rows x 6 columns]

# %%
df_subway
# Out:
#                                  NAME  \
# 0    W 4th St - Washington Sq (Lower)
# 1                           Buhre Ave
# 2                             51st St
# 3                             86th St
# 4         Brooklyn Bridge - City Hall
# ..                                ...
# 466               5th Ave - Bryant Pk
# 467                         Spring St
# 468                          125th St
# 469       Coney Island - Stillwell Av
# 470                               NaN
#
#                                           the_geom  \
# 0     POINT (-74.00030814706824 40.73225482650675)
# 1    POINT (-73.83256899924748 40.846810332614844)
# 2    POINT (-73.97192000013308 40.757107333148234)
# 3     POINT (-73.97621799811347 40.78864433404891)
# 4    POINT (-74.00413100111697 40.713065332984044)
# ..                                             ...
# 466   POINT (-73.98196299871373 40.75382133359373)
# 467   POINT (-73.99714099950617 40.72230133331719)
# 468  POINT (-73.93759400019064 40.804138334029325)
# 469   POINT (-73.98123599855974 40.57728133344397)
# 470                                            NaN
#
#                                             URL             LINE  Unnamed: 4  \
# 0    http://www.mta.info/nyct/subway/index.html          B-D-F-M         NaN
# 1    http://www.mta.info/nyct/subway/index.html      6-6 Express         NaN
# 2    http://www.mta.info/nyct/subway/index.html    4-6-6 Express         NaN
# 3    http://www.mta.info/nyct/subway/index.html            2-Jan         NaN
# 4    http://www.mta.info/nyct/subway/index.html  4-5-6-6 Express         NaN
# ..                                          ...              ...         ...
# 466  http://www.mta.info/nyct/subway/index.html      7-7 Express         NaN
# 467  http://www.mta.info/nyct/subway/index.html    4-6-6 Express         NaN
# 468  http://www.mta.info/nyct/subway/index.html  4-5-6-6 Express         NaN
# 469  http://www.mta.info/nyct/subway/index.html          D-F-N-Q         NaN
# 470                                         NaN              NaN         NaN
#
#                                    Unnamed: 5               Unnamed: 6  \
# 0    POINT (-74.00030814706824 40.73225482650  POINT (-74.000308147068
# 1    POINT (-73.83256899924748 40.84681033261  POINT (-73.832568999247
# 2    POINT (-73.97192000013308 40.75710733314  POINT (-73.971920000133
# 3    POINT (-73.97621799811347 40.78864433404  POINT (-73.976217998113
# 4    POINT (-74.00413100111697 40.71306533298  POINT (-74.004131001116
# ..                                        ...                      ...
# 466  POINT (-73.98196299871373 40.75382133359  POINT (-73.981962998713
# 467  POINT (-73.99714099950617 40.72230133331  POINT (-73.997140999506
# 468  POINT (-73.93759400019064 40.80413833402  POINT (-73.937594000190
# 469  POINT (-73.98123599855974 40.57728133344  POINT (-73.981235998559
# 470                                       NaN                      NaN
#
#             Latitude  Longitude
# 0     40.73225482650 -74.000308
# 1     40.84681033261 -73.832569
# 2     40.75710733314 -73.971920
# 3     40.78864433404 -73.976218
# 4     40.71306533298 -74.004131
# ..               ...        ...
# 466   40.75382133359 -73.981963
# 467   40.72230133331 -73.997141
# 468   40.80413833402 -73.937594
# 469   40.57728133344 -73.981236
# 470              NaN        NaN
#
# [471 rows x 9 columns]

# %%
name_loc=['NAME',"Latitude","Longitude"]
subway=df_subway[name_loc].dropna()

# %%
subway
# Out:
#                                  NAME         Latitude  Longitude
# 0    W 4th St - Washington Sq (Lower)   40.73225482650 -74.000308
# 1                           Buhre Ave   40.84681033261 -73.832569
# 2                             51st St   40.75710733314 -73.971920
# 3                             86th St   40.78864433404 -73.976218
# 4         Brooklyn Bridge - City Hall   40.71306533298 -74.004131
# ..                                ...              ...        ...
# 465                           80th St   40.67937133457 -73.858992
# 466               5th Ave - Bryant Pk   40.75382133359 -73.981963
# 467                         Spring St   40.72230133331 -73.997141
# 468                          125th St   40.80413833402 -73.937594
# 469       Coney Island - Stillwell Av   40.57728133344 -73.981236
#
# [470 rows x 3 columns]

# %%
# subway.to_csv('SubwayGPS.csv')

# %%
import pandas as pd
def ClosestStop(r):
    # Cartesin Distance: square root of (x2-x2)^2 + (y2-y1)^2
    distances = ((r['lat']-StationDf['LATITUDE'])**2 + (r['lon']-StationDf['LONGITUDE'])**2)**0.5
    
    # Stop with minimum Distance from the Suburb
    closestStationId = distances[distances == distances.min()].index.to_list()[0]
    return StationDf.loc[closestStationId, ['STOP_ID', 'STOP_NAME']]

StationDf = pd.read_excel("StationData.xlsx")
SuburbDf = pd.read_excel("SuburbData.xlsx")

SuburbDf[['ClosestStopId', 'ClosestStopName']] = SuburbDf.apply(ClosestStop, axis=1)
print(SuburbDf)

# %%
NY_COORDINATES = (40.7, -74.0)
ny_map = folium.Map(location=NY_COORDINATES, zoom_start=15)

display(ny_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f02c1314a91a4e6dad0230b6f5378fc3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f02c1314a91a4e6dad0230b6f5378fc3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f02c1314a91a4e6dad0230b6f5378fc3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f02c1314a91a4e6dad0230b6f5378fc3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7%2C%20-74.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %%
m = folium.Map(location=[45.5236, -122.6750])

# %%
locations = df_OPA[['Latitude', 'Longitude']].astype('float')
heatmap = folium.plugins.HeatMap(locations.values, radius = 10)
ny_map.add_child(heatmap)
display(ny_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f02c1314a91a4e6dad0230b6f5378fc3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f02c1314a91a4e6dad0230b6f5378fc3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f02c1314a91a4e6dad0230b6f5378fc3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f02c1314a91a4e6dad0230b6f5378fc3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
# nycmap=json.load(open(r'C:\Users\user\OneDrive\Desktop\nycpluto_manhattan.geojson'))
# nycmap

# %%
locations
# Out:
#         Latitude  Longitude
# 0      40.724971 -74.004477
# 1      40.730073 -73.986585
# 2      40.747630 -73.891596
# 3      40.678651 -73.978934
# 4      40.724625 -74.003889
# ...          ...        ...
# 12252  40.748554 -74.003533
# 12253  40.723347 -73.952118
# 12254  40.780874 -73.917406
# 12255  40.784739 -73.845776
# 12256  40.766927 -73.986423
#
# [10967 rows x 2 columns]

# %%
# df_RestaurantLoc['Latitude']=df_RestaurantLoc['Latitude'].apply(func=math.radians)
# df_RestaurantLoc['Longitude']=df_RestaurantLoc['Longitude'].apply(func=math.radians)
# df_RestaurantLoc['Coord']=df_RestaurantLoc(zip(df_RestaurantLoc['Latitude'],df_RestaurantLoc['Longitude']))

# %%
df_RestaurantLoc
# Out:
#                        Restaurant Name   Latitude  Longitude  \
# 1                              MEYHANE  40.730073 -73.986585
# 2      Prince Laban&Chinese restaurent  40.747630 -73.891596
# 5                        BICKLES TO GO  40.820750 -73.917653
# 9                Le Pain Quotidien GCW  40.754434 -73.979138
# 11            35-09 Ditmars Bagel Corp  40.774763 -73.908748
# ...                                ...        ...        ...
# 12248                       PINK MOOSE  40.759173 -73.962283
# 12249                         JACKSONS  40.742309 -73.953104
# 12254                Astoria Ale House  40.780874 -73.917406
# 12255              KING OF SPADES INC.  40.784739 -73.845776
# 12256                 KASHKAVAL GARDEN  40.766927 -73.986423
#
#       Sidewalk Dimensions (Area) Roadway Dimensions (Area)  \
# 1                            512                       256
# 2                            144                       144
# 5                            100                       160
# 9                             90                       240
# 11                            40                       160
# ...                          ...                       ...
# 12248                        180                       160
# 12249                        616                       476
# 12254                        160                       160
# 12255                         88                       176
# 12256                         30                        30
#
#            Time of Submission
# 1      04/22/2021 02:41:00 PM
# 2      08/15/2020 04:55:00 PM
# 5      08/17/2020 10:29:00 AM
# 9      08/17/2020 09:46:00 AM
# 11     08/16/2020 05:22:00 PM
# ...                       ...
# 12248  12/02/2020 02:37:00 PM
# 12249  07/24/2020 04:31:00 PM
# 12254  07/23/2020 08:56:00 PM
# 12255  08/04/2020 03:27:00 PM
# 12256  06/30/2020 10:33:00 PM
#
# [5699 rows x 6 columns]
